# %% [markdown]
# <a href="https://colab.research.google.com/github/KarinVe/wotech-python-2024/blob/main/1506_class_births_deaths_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = '/content/births.txt' #location (copy path)
# this is how to open file without external library, just using Python.
with open(filename, 'r') as file:
    content = file.read()

print('Standard File I/O') # This is providing output that is not easy to work with, the data is as one string. Sometimes it is good to have it in one string
print(content)
# Out:
# Standard File I/O
# Jan 1048
# Feb 989
# Mar 1108
# Apr 1207
# May 1186
# Jun 1155
# Jul 1391
# Aug 1305
# Sep 1226
# Oct 1155
# Nov 1017
# Dec 1111

# %%
for line in content:  # Our program does not understand that we have different columns, it handles it as one string
    print(line)
# Out:
# J
# a
# n
#
# 1
# 0
# 4
# 8
#
#
# F
# e
# b
#
# 9
# 8
# 9
#
#
# M
# a
# r
#
# 1
# 1
# 0
# 8
#
#
# A
# p
# r
#
# 1
# 2
# 0
# 7
#
#
# M
# a
# y
#
# 1
# 1
# 8
# 6
#
#
# J
# u
# n
#
# 1
# 1
# 5
# 5
#
#
# J
# u
# l
#
# 1
# 3
# 9
# 1
#
#
# A
# u
# g
#
# 1
# 3
# 0
# 5
#
#
# S
# e
# p
#
# 1
# 2
# 2
# 6
#
#
# O
# c
# t
#
# 1
# 1
# 5
# 5
#
#
# N
# o
# v
#
# 1
# 0
# 1
# 7
#
#
# D
# e
# c
#
# 1
# 1
# 1
# 1

# %% [markdown]
# ###READLINES

# %%
filename = '/content/births.txt' #location

with open(filename, 'r') as file:
    content = file.readlines() #we use readlines instead of read here, because the read format is difficult to work with, it does not understand where are columns and rows
                                #now we have list objects to work with
print('Standard File I/O')
print(content)
# Out:
# Standard File I/O
# ['Jan 1048\n', 'Feb 989\n', 'Mar 1108\n', 'Apr 1207\n', 'May 1186\n', 'Jun 1155\n', 'Jul 1391\n', 'Aug 1305\n', 'Sep 1226\n', 'Oct 1155\n', 'Nov 1017\n', 'Dec 1111\n']

# %%
for line in content:
    print(line, end='')
# Out:
# Jan 1048
# Feb 989
# Mar 1108
# Apr 1207
# May 1186
# Jun 1155
# Jul 1391
# Aug 1305
# Sep 1226
# Oct 1155
# Nov 1017
# Dec 1111

# %% [markdown]
# Modify the code, make file name as input from the user, and enclose the code in try, except if file is not found

# %%
filename = input('Please enter the filename: ')

try:
    with open(filename, 'r') as file:
        content = file.readlines()
        print('Standard File I/O')
        print(content)
except:
    print('Invalid filename')
# Out:
# Please enter the filename: deaths.txt
# Standard File I/O
# ['Jan 1575\n', 'Feb 1167\n', 'Mar 1249\n', 'Apr 1281\n', 'May 1303\n', 'Jun 1115\n', 'Jul 1327\n', 'Aug 1202\n', 'Sep 1177\n', 'Oct 1265\n', 'Nov 1218\n', 'Dec 1359\n']

# %%
#births
with open('births.txt', 'r') as file:
    births = file.readlines()

# %%
for birthline in births:
    print(birthline[4:])
# Out:
# 1048
#
# 989
#
# 1108
#
# 1207
#
# 1186
#
# 1155
#
# 1391
#
# 1305
#
# 1226
#
# 1155
#
# 1017
#
# 1111

# %% [markdown]
# Sum up all the elements

# %%
total_sum = 0
for birthline in births:
    total_sum += int(birthline[4:])

print(total_sum)
# Out:
# 13898

# %% [markdown]
# The file births.txt contains the number of births in Estonia for a
# certain time period by months, while the file deaths.txt contains the
# number of deaths.
# Write a program that finds and outputs the months when the natural
# population growth was positive and its size.
# Update your program so that it also finds and outputs the natural
# population growth for the entire period covered in the files.

# %%
#births
with open('/content/births.txt', 'r') as file:
    births = file.readlines() #LIST, separated by comma

#deaths
with open('/content/deaths.txt', 'r') as file:
    deaths = file.readlines()

# %%
len(births) == len(deaths)
# Out:
# True

# %%
#accessing the number: int(birthline[4:])

for i in range(len(births)):
    birthline = births[i]
    deathline = deaths[i]

    birthnumber = int(birthline[4:])
    deathnumber = int(deathline[4:])

    growth = birthnumber - deathnumber
    month = birthline[:3]
    if growth > 0:
        print(month, growth)
# Out:
# Jun 40
# Jul 64
# Aug 103
# Sep 49

# %% [markdown]
# Task (in your free time): put all this in a function, where parameters are deaths.txt and births.txt
# input parameters are file nr 1 and file nr 2

# %%
def population_growth(births_file, deaths_file):

    with open(births_file, 'r') as file:
        births = file.readlines()

    with open(deaths_file, 'r') as file:
        deaths = file.readlines()

    for i in range(len(births)):
        birthline = births[i]
        deathline = deaths[i]

        birthnumber = int(birthline[4:])
        deathnumber = int(deathline[4:])

        growth = birthnumber - deathnumber
        month = birthline[:3]
        if growth > 0:
            print(month, growth)

population_growth('/content/births.txt', '/content/deaths.txt')
# Out:
# Jun 40
# Jul 64
# Aug 103
# Sep 49

# %% [markdown]
# ###PANDAS

# %%
import pandas as pd #anything else could also work

# %%
births = pd.read_csv('/content/births.txt', header = None, delimiter = ' ') #you can read in many different file types

# %%
birth_column_names = ['Month', 'Nr.Births']
births.columns = birth_column_names
births
# Out:
#    Month  Nr.Births
# 0    Jan       1048
# 1    Feb        989
# 2    Mar       1108
# 3    Apr       1207
# 4    May       1186
# 5    Jun       1155
# 6    Jul       1391
# 7    Aug       1305
# 8    Sep       1226
# 9    Oct       1155
# 10   Nov       1017
# 11   Dec       1111

# %%
deaths = pd.read_csv('/content/deaths.txt', header = None, delimiter = ' ') #you can read in many different file types
death_column_names = ['Month', 'Nr.Deaths']
deaths.columns = death_column_names
deaths
# Out:
#    Month  Nr.Deaths
# 0    Jan       1575
# 1    Feb       1167
# 2    Mar       1249
# 3    Apr       1281
# 4    May       1303
# 5    Jun       1115
# 6    Jul       1327
# 7    Aug       1202
# 8    Sep       1177
# 9    Oct       1265
# 10   Nov       1218
# 11   Dec       1359

# %%
#our dataframes are the same length, lets assume our main dataframe is the birth dataframe
#we created 'Saldo' first, and then changed. Now there are both 'Saldo' and 'difference_between...' until we remove one of them

births['difference_between_births_deaths'] = births['Nr.Births'] - deaths['Nr.Deaths']

# %%
births['Nr. of deaths'] = deaths['Nr.Deaths']

# %%
births
# Out:
#    Month  Nr.Births  Saldo  difference_between_births_deaths  Nr. of deaths
# 0    Jan       1048   -527                              -527           1575
# 1    Feb        989   -178                              -178           1167
# 2    Mar       1108   -141                              -141           1249
# 3    Apr       1207    -74                               -74           1281
# 4    May       1186   -117                              -117           1303
# 5    Jun       1155     40                                40           1115
# 6    Jul       1391     64                                64           1327
# 7    Aug       1305    103                               103           1202
# 8    Sep       1226     49                                49           1177
# 9    Oct       1155   -110                              -110           1265
# 10   Nov       1017   -201                              -201           1218
# ...

# %%
#EXPORTING
file_name = '/content/output.csv'
births.to_csv(file_name, index=False) # index = False, so you do not get index in your csv file
